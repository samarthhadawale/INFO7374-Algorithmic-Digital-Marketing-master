# %%
#################################################
# This script reads image feature vectors from a folder
# and saves the image similarity scores in json file
# by Erdem Isbilen - December/2019
#################################################

# %%
#################################################
# Imports and function definitions
#################################################

# Numpy for loading image feature vectors from file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path

# json for storing data in json file
import json
import requests

# Annoy and Scipy for similarity calculation
from annoy import AnnoyIndex
from scipy import spatial
#################################################
import time

# %%
# This function reads from 'image_data.json' file
# Looks for a specific 'filename' value
# Returns the product id when product image names are matched 
# So it is used to find product id based on the product image name
#################################################
def match_id(filename):
  with open('image_data.json') as json_file:
    
    for file in json_file:
        seen = json.loads(file)

        for line in seen:
          
          if filename==line['imageName']:
            print(line)
            return line['productId']
            break
#################################################

# %%
#################################################
# This function; 
# Reads all image feature vectores stored in /feature-vectors/*.npz
# Adds them all in Annoy Index
# Builds ANNOY index
# Calculates the nearest neighbors and image similarity metrics
# Stores image similarity scores with productID in a json file
#################################################
def cluster():

  start_time = time.time()
  
  print("---------------------------------")
  print ("Step.1 - ANNOY index generation - Started at %s" %time.ctime())
  print("---------------------------------")

  # Defining data structures as empty dict
  file_index_to_file_name = {}
  file_index_to_file_vector = {}
  file_index_to_product_id = {}

  # Configuring annoy parameters
  dims = 1792
  n_nearest_neighbors = 5
  trees = 10000

  # Reads all file names which stores feature vectors 
  allfiles = glob.glob('test/*.npz')

  t = AnnoyIndex(dims, metric='angular')

  for file_index, i in enumerate(allfiles):
    
    # Reads feature vectors and assigns them into the file_vector 
    file_vector = np.loadtxt(i)

    # Assigns file_name, feature_vectors and corresponding product_id
    file_name = os.path.basename(i).split('.')[0]
    file_index_to_file_name[file_index] = file_name
    file_index_to_file_vector[file_index] = file_vector
    file_index_to_product_id[file_index] = match_id(file_name)

    # Adds image feature vectors into annoy index   
    t.add_item(file_index, file_vector)

    print("---------------------------------")
    print("Annoy index     : %s" %file_index)
    print("Image file name : %s" %file_name)
    print("Product id      : %s" %file_index_to_product_id[file_index])
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))


  # Builds annoy index
  t.build(trees)

  print ("Step.1 - ANNOY index generation - Finished")
  print ("Step.2 - Similarity score calculation - Started ") 
  
  named_nearest_neighbors = []

  # Loops through all indexed items
  for i in file_index_to_file_name.keys():

    # Assigns master file_name, image feature vectors and product id values
    master_file_name = file_index_to_file_name[i]
    master_vector = file_index_to_file_vector[i]
    master_product_id = file_index_to_product_id[i]

    # Calculates the nearest neighbors of the master item
    nearest_neighbors = t.get_nns_by_item(i, n_nearest_neighbors)

    # Loops through the nearest neighbors of the master item
    for j in nearest_neighbors:

      print(j)

      # Assigns file_name, image feature vectors and product id values of the similar item
      neighbor_file_name = file_index_to_file_name[j]
      neighbor_file_vector = file_index_to_file_vector[j]
      neighbor_product_id = file_index_to_product_id[j]

      # Calculates the similarity score of the similar item
      similarity = 1 - spatial.distance.cosine(master_vector, neighbor_file_vector)
      rounded_similarity = int((similarity * 10000)) / 10000.0

      # Appends master product id with the similarity score 
      # and the product id of the similar items
      named_nearest_neighbors.append({
        'similarity': rounded_similarity,
        'master_pi': master_product_id,
        'similar_pi': neighbor_product_id})

    print("---------------------------------") 
    print("Similarity index       : %s" %i)
    print("Master Image file name : %s" %file_index_to_file_name[i]) 
    print("Nearest Neighbors.     : %s" %nearest_neighbors) 
    print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  
  print ("Step.2 - Similarity score calculation - Finished ") 

  # Writes the 'named_nearest_neighbors' to a json file
  with open('nearest_neighbors.json', 'w') as out:
    json.dump(named_nearest_neighbors, out)

  print ("Step.3 - Data stored in 'nearest_neighbors.json' file ") 
  print("--- Prosess completed in %.2f minutes ---------" % ((time.time() - start_time)/60))

cluster()
# Out:
# ---------------------------------
# Step.1 - ANNOY index generation - Started at Fri Jul 10 17:44:16 2020
# ---------------------------------
# {'imageName': '34762_2', 'productId': '33'}
# ---------------------------------
# Annoy index     : 0
# Image file name : 34762_2
# Product id      : 33
# --- 0.00 minutes passed ---------
# {'imageName': '34762_0', 'productId': '31'}
# ---------------------------------
# Annoy index     : 1
# Image file name : 34762_0
# Product id      : 31
# --- 0.00 minutes passed ---------
# {'imageName': '34762_1', 'productId': '32'}
# ---------------------------------
# Annoy index     : 2
# Image file name : 34762_1
# Product id      : 32
# --- 0.00 minutes passed ---------
# {'imageName': '12688_0', 'productId': '4'}
# ---------------------------------
# Annoy index     : 3
# Image file name : 12688_0
# Product id      : 4
# --- 0.00 minutes passed ---------
# {'imageName': '36756_3', 'productId': '39'}
# ---------------------------------
# Annoy index     : 4
# Image file name : 36756_3
# Product id      : 39
# --- 0.00 minutes passed ---------
# {'imageName': '36756_2', 'productId': '38'}
# ---------------------------------
# Annoy index     : 5
# Image file name : 36756_2
# Product id      : 38
# --- 0.00 minutes passed ---------
# {'imageName': '12688_1', 'productId': '5'}
# ---------------------------------
# Annoy index     : 6
# Image file name : 12688_1
# Product id      : 5
# --- 0.00 minutes passed ---------
# {'imageName': '36756_0', 'productId': '36'}
# ---------------------------------
# Annoy index     : 7
# Image file name : 36756_0
# Product id      : 36
# --- 0.00 minutes passed ---------
# {'imageName': '36756_1', 'productId': '37'}
# ---------------------------------
# Annoy index     : 8
# Image file name : 36756_1
# Product id      : 37
# --- 0.00 minutes passed ---------
# {'imageName': '43354_2', 'productId': '43'}
# ---------------------------------
# Annoy index     : 9
# Image file name : 43354_2
# Product id      : 43
# --- 0.00 minutes passed ---------
# {'imageName': '49335_0', 'productId': '44'}
# ---------------------------------
# Annoy index     : 10
# Image file name : 49335_0
# Product id      : 44
# --- 0.00 minutes passed ---------
# {'imageName': '17518_3', 'productId': '13'}
# ---------------------------------
# Annoy index     : 11
# Image file name : 17518_3
# Product id      : 13
# --- 0.00 minutes passed ---------
# {'imageName': '17518_2', 'productId': '12'}
# ---------------------------------
# Annoy index     : 12
# Image file name : 17518_2
# Product id      : 12
# --- 0.00 minutes passed ---------
# {'imageName': '49335_1', 'productId': '45'}
# ---------------------------------
# Annoy index     : 13
# Image file name : 49335_1
# Product id      : 45
# --- 0.00 minutes passed ---------
# {'imageName': '30918_2', 'productId': '26'}
# ---------------------------------
# Annoy index     : 14
# Image file name : 30918_2
# Product id      : 26
# --- 0.00 minutes passed ---------
# {'imageName': '43354_1', 'productId': '42'}
# ---------------------------------
# Annoy index     : 15
# Image file name : 43354_1
# Product id      : 42
# --- 0.00 minutes passed ---------
# {'imageName': '30918_0', 'productId': '24'}
# ---------------------------------
# Annoy index     : 16
# Image file name : 30918_0
# Product id      : 24
# --- 0.00 minutes passed ---------
# {'imageName': '17518_0', 'productId': '10'}
# ---------------------------------
# Annoy index     : 17
# Image file name : 17518_0
# Product id      : 10
# --- 0.00 minutes passed ---------
# {'imageName': '35231_0', 'productId': '34'}
# ---------------------------------
# Annoy index     : 18
# Image file name : 35231_0
# Product id      : 34
# --- 0.00 minutes passed ---------
# {'imageName': '35231_1', 'productId': '35'}
# ---------------------------------
# Annoy index     : 19
# Image file name : 35231_1
# Product id      : 35
# --- 0.00 minutes passed ---------
# {'imageName': '17518_1', 'productId': '11'}
# ---------------------------------
# Annoy index     : 20
# Image file name : 17518_1
# Product id      : 11
# --- 0.00 minutes passed ---------
# {'imageName': '30918_1', 'productId': '25'}
# ---------------------------------
# Annoy index     : 21
# Image file name : 30918_1
# Product id      : 25
# --- 0.00 minutes passed ---------
# {'imageName': '43354_0', 'productId': '41'}
# ---------------------------------
# Annoy index     : 22
# Image file name : 43354_0
# Product id      : 41
# --- 0.00 minutes passed ---------
# {'imageName': '20730_1', 'productId': '15'}
# ---------------------------------
# Annoy index     : 23
# Image file name : 20730_1
# Product id      : 15
# --- 0.00 minutes passed ---------
# {'imageName': '20730_0', 'productId': '14'}
# ---------------------------------
# Annoy index     : 24
# Image file name : 20730_0
# Product id      : 14
# --- 0.00 minutes passed ---------
# ---------------------------------
# Annoy index     : 25
# Image file name : 20730_2
# Product id      : None
# --- 0.00 minutes passed ---------
# {'imageName': '20730_3', 'productId': '16'}
# ---------------------------------
# Annoy index     : 26
# Image file name : 20730_3
# Product id      : 16
# --- 0.00 minutes passed ---------
# {'imageName': '38983_0', 'productId': '40'}
# ---------------------------------
# Annoy index     : 27
# Image file name : 38983_0
# Product id      : 40
# --- 0.00 minutes passed ---------
# {'imageName': '12600_0', 'productId': '3'}
# ---------------------------------
# Annoy index     : 28
# Image file name : 12600_0
# Product id      : 3
# --- 0.00 minutes passed ---------
# {'imageName': '49884_0', 'productId': '46'}
# ---------------------------------
# Annoy index     : 29
# Image file name : 49884_0
# Product id      : 46
# --- 0.00 minutes passed ---------
# {'imageName': '17126_3', 'productId': '9'}
# ---------------------------------
# Annoy index     : 30
# Image file name : 17126_3
# Product id      : 9
# --- 0.00 minutes passed ---------
# {'imageName': '17126_2', 'productId': '8'}
# ---------------------------------
# Annoy index     : 31
# Image file name : 17126_2
# Product id      : 8
# --- 0.00 minutes passed ---------
# {'imageName': '17126_0', 'productId': '6'}
# ---------------------------------
# Annoy index     : 32
# Image file name : 17126_0
# Product id      : 6
# --- 0.00 minutes passed ---------
# {'imageName': '17126_1', 'productId': '7'}
# ---------------------------------
# Annoy index     : 33
# Image file name : 17126_1
# Product id      : 7
# --- 0.00 minutes passed ---------
# {'imageName': '21857_2', 'productId': '20'}
# ---------------------------------
# Annoy index     : 34
# Image file name : 21857_2
# Product id      : 20
# --- 0.00 minutes passed ---------
# {'imageName': '52536_3', 'productId': '50'}
# ---------------------------------
# Annoy index     : 35
# Image file name : 52536_3
# Product id      : 50
# --- 0.00 minutes passed ---------
# {'imageName': '9905_1', 'productId': '2'}
# ---------------------------------
# Annoy index     : 36
# Image file name : 9905_1
# Product id      : 2
# --- 0.00 minutes passed ---------
# {'imageName': '33220_2', 'productId': '29'}
# ---------------------------------
# Annoy index     : 37
# Image file name : 33220_2
# Product id      : 29
# --- 0.00 minutes passed ---------
# {'imageName': '33220_3', 'productId': '30'}
# ---------------------------------
# Annoy index     : 38
# Image file name : 33220_3
# Product id      : 30
# --- 0.00 minutes passed ---------
# {'imageName': '9905_0', 'productId': '1'}
# ---------------------------------
# Annoy index     : 39
# Image file name : 9905_0
# Product id      : 1
# --- 0.00 minutes passed ---------
# {'imageName': '52536_2', 'productId': '49'}
# ---------------------------------
# Annoy index     : 40
# Image file name : 52536_2
# Product id      : 49
# --- 0.00 minutes passed ---------
# {'imageName': '21857_3', 'productId': '21'}
# ---------------------------------
# Annoy index     : 41
# Image file name : 21857_3
# Product id      : 21
# --- 0.00 minutes passed ---------
# {'imageName': '21857_1', 'productId': '19'}
# ---------------------------------
# Annoy index     : 42
# Image file name : 21857_1
# Product id      : 19
# --- 0.00 minutes passed ---------
# {'imageName': '52536_0', 'productId': '47'}
# ---------------------------------
# Annoy index     : 43
# Image file name : 52536_0
# Product id      : 47
# --- 0.00 minutes passed ---------
# {'imageName': '33220_1', 'productId': '28'}
# ---------------------------------
# Annoy index     : 44
# Image file name : 33220_1
# Product id      : 28
# --- 0.00 minutes passed ---------
# {'imageName': '29000_1', 'productId': '23'}
# ---------------------------------
# Annoy index     : 45
# Image file name : 29000_1
# Product id      : 23
# --- 0.00 minutes passed ---------
# {'imageName': '29000_0', 'productId': '22'}
# ---------------------------------
# Annoy index     : 46
# Image file name : 29000_0
# Product id      : 22
# --- 0.00 minutes passed ---------
# {'imageName': '33220_0', 'productId': '27'}
# ---------------------------------
# Annoy index     : 47
# Image file name : 33220_0
# Product id      : 27
# --- 0.00 minutes passed ---------
# {'imageName': '52536_1', 'productId': '48'}
# ---------------------------------
# Annoy index     : 48
# Image file name : 52536_1
# Product id      : 48
# --- 0.01 minutes passed ---------
# {'imageName': '21857_0', 'productId': '18'}
# ---------------------------------
# Annoy index     : 49
# Image file name : 21857_0
# Product id      : 18
# --- 0.01 minutes passed ---------
# Step.1 - ANNOY index generation - Finished
# Step.2 - Similarity score calculation - Started
# 0
# 2
# 6
# 11
# 12
# ---------------------------------
# Similarity index       : 0
# Master Image file name : 34762_2
# Nearest Neighbors.     : [0, 2, 6, 11, 12]
# --- 0.01 minutes passed ---------
# 1
# 49
# 17
# 11
# 2
# ---------------------------------
# Similarity index       : 1
# Master Image file name : 34762_0
# Nearest Neighbors.     : [1, 49, 17, 11, 2]
# --- 0.01 minutes passed ---------
# 2
# 11
# 0
# 24
# 1
# ---------------------------------
# Similarity index       : 2
# Master Image file name : 34762_1
# Nearest Neighbors.     : [2, 11, 0, 24, 1]
# --- 0.01 minutes passed ---------
# 3
# 6
# 29
# 43
# 35
# ---------------------------------
# Similarity index       : 3
# Master Image file name : 12688_0
# Nearest Neighbors.     : [3, 6, 29, 43, 35]
# --- 0.01 minutes passed ---------
# 4
# 8
# 5
# 7
# 21
# ---------------------------------
# Similarity index       : 4
# Master Image file name : 36756_3
# Nearest Neighbors.     : [4, 8, 5, 7, 21]
# --- 0.01 minutes passed ---------
# 5
# 8
# 7
# 4
# 21
# ---------------------------------
# Similarity index       : 5
# Master Image file name : 36756_2
# Nearest Neighbors.     : [5, 8, 7, 4, 21]
# --- 0.01 minutes passed ---------
# 6
# 3
# 29
# 43
# 0
# ---------------------------------
# Similarity index       : 6
# Master Image file name : 12688_1
# Nearest Neighbors.     : [6, 3, 29, 43, 0]
# --- 0.01 minutes passed ---------
# 7
# 8
# 5
# 21
# 20
# ---------------------------------
# Similarity index       : 7
# Master Image file name : 36756_0
# Nearest Neighbors.     : [7, 8, 5, 21, 20]
# --- 0.01 minutes passed ---------
# 8
# 7
# 5
# 4
# 21
# ---------------------------------
# Similarity index       : 8
# Master Image file name : 36756_1
# Nearest Neighbors.     : [8, 7, 5, 4, 21]
# --- 0.01 minutes passed ---------
# 9
# 28
# 1
# 21
# 38
# ---------------------------------
# Similarity index       : 9
# Master Image file name : 43354_2
# Nearest Neighbors.     : [9, 28, 1, 21, 38]
# --- 0.01 minutes passed ---------
# 10
# 13
# 18
# 30
# 31
# ---------------------------------
# Similarity index       : 10
# Master Image file name : 49335_0
# Nearest Neighbors.     : [10, 13, 18, 30, 31]
# --- 0.01 minutes passed ---------
# 11
# 20
# 27
# 12
# 40
# ---------------------------------
# Similarity index       : 11
# Master Image file name : 17518_3
# Nearest Neighbors.     : [11, 20, 27, 12, 40]
# --- 0.01 minutes passed ---------
# 12
# 20
# 11
# 47
# 27
# ---------------------------------
# Similarity index       : 12
# Master Image file name : 17518_2
# Nearest Neighbors.     : [12, 20, 11, 47, 27]
# --- 0.01 minutes passed ---------
# 13
# 10
# 30
# 31
# 32
# ---------------------------------
# Similarity index       : 13
# Master Image file name : 49335_1
# Nearest Neighbors.     : [13, 10, 30, 31, 32]
# --- 0.01 minutes passed ---------
# 14
# 16
# 21
# 27
# 11
# ---------------------------------
# Similarity index       : 14
# Master Image file name : 30918_2
# Nearest Neighbors.     : [14, 16, 21, 27, 11]
# --- 0.01 minutes passed ---------
# 15
# 22
# 46
# 18
# 24
# ---------------------------------
# Similarity index       : 15
# Master Image file name : 43354_1
# Nearest Neighbors.     : [15, 22, 46, 18, 24]
# --- 0.01 minutes passed ---------
# 16
# 14
# 11
# 21
# 20
# ---------------------------------
# Similarity index       : 16
# Master Image file name : 30918_0
# Nearest Neighbors.     : [16, 14, 11, 21, 20]
# --- 0.01 minutes passed ---------
# 17
# 20
# 8
# 7
# 5
# ---------------------------------
# Similarity index       : 17
# Master Image file name : 17518_0
# Nearest Neighbors.     : [17, 20, 8, 7, 5]
# --- 0.01 minutes passed ---------
# 18
# 19
# 10
# 26
# 24
# ---------------------------------
# Similarity index       : 18
# Master Image file name : 35231_0
# Nearest Neighbors.     : [18, 19, 10, 26, 24]
# --- 0.01 minutes passed ---------
# 19
# 26
# 18
# 24
# 23
# ---------------------------------
# Similarity index       : 19
# Master Image file name : 35231_1
# Nearest Neighbors.     : [19, 26, 18, 24, 23]
# --- 0.01 minutes passed ---------
# 20
# 12
# 11
# 17
# 7
# ---------------------------------
# Similarity index       : 20
# Master Image file name : 17518_1
# Nearest Neighbors.     : [20, 12, 11, 17, 7]
# --- 0.01 minutes passed ---------
# 21
# 7
# 8
# 5
# 4
# ---------------------------------
# Similarity index       : 21
# Master Image file name : 30918_1
# Nearest Neighbors.     : [21, 7, 8, 5, 4]
# --- 0.01 minutes passed ---------
# 22
# 15
# 18
# 19
# 26
# ---------------------------------
# Similarity index       : 22
# Master Image file name : 43354_0
# Nearest Neighbors.     : [22, 15, 18, 19, 26]
# --- 0.01 minutes passed ---------
# 23
# 26
# 24
# 19
# 18
# ---------------------------------
# Similarity index       : 23
# Master Image file name : 20730_1
# Nearest Neighbors.     : [23, 26, 24, 19, 18]
# --- 0.01 minutes passed ---------
# 24
# 26
# 19
# 23
# 18
# ---------------------------------
# Similarity index       : 24
# Master Image file name : 20730_0
# Nearest Neighbors.     : [24, 26, 19, 23, 18]
# --- 0.01 minutes passed ---------
# 25
# 30
# 31
# 32
# 33
# ---------------------------------
# Similarity index       : 25
# Master Image file name : 20730_2
# Nearest Neighbors.     : [25, 30, 31, 32, 33]
# --- 0.01 minutes passed ---------
# 26
# 19
# 24
# 23
# 18
# ---------------------------------
# Similarity index       : 26
# Master Image file name : 20730_3
# Nearest Neighbors.     : [26, 19, 24, 23, 18]
# --- 0.01 minutes passed ---------
# 27
# 11
# 28
# 20
# 12
# ---------------------------------
# Similarity index       : 27
# Master Image file name : 38983_0
# Nearest Neighbors.     : [27, 11, 28, 20, 12]
# --- 0.01 minutes passed ---------
# 28
# 27
# 13
# 9
# 39
# ---------------------------------
# Similarity index       : 28
# Master Image file name : 12600_0
# Nearest Neighbors.     : [28, 27, 13, 9, 39]
# --- 0.01 minutes passed ---------
# 29
# 24
# 19
# 26
# 18
# ---------------------------------
# Similarity index       : 29
# Master Image file name : 49884_0
# Nearest Neighbors.     : [29, 24, 19, 26, 18]
# --- 0.01 minutes passed ---------
# 30
# 31
# 32
# 33
# 10
# ---------------------------------
# Similarity index       : 30
# Master Image file name : 17126_3
# Nearest Neighbors.     : [30, 31, 32, 33, 10]
# --- 0.01 minutes passed ---------
# 30
# 31
# 32
# 33
# 10
# ---------------------------------
# Similarity index       : 31
# Master Image file name : 17126_2
# Nearest Neighbors.     : [30, 31, 32, 33, 10]
# --- 0.01 minutes passed ---------
# 30
# 31
# 32
# 33
# 10
# ---------------------------------
# Similarity index       : 32
# Master Image file name : 17126_0
# Nearest Neighbors.     : [30, 31, 32, 33, 10]
# --- 0.01 minutes passed ---------
# 30
# 31
# 32
# 33
# 10
# ---------------------------------
# Similarity index       : 33
# Master Image file name : 17126_1
# Nearest Neighbors.     : [30, 31, 32, 33, 10]
# --- 0.01 minutes passed ---------
# 34
# 42
# 45
# 38
# 49
# ---------------------------------
# Similarity index       : 34
# Master Image file name : 21857_2
# Nearest Neighbors.     : [34, 42, 45, 38, 49]
# --- 0.01 minutes passed ---------
# 35
# 48
# 43
# 40
# 11
# ---------------------------------
# Similarity index       : 35
# Master Image file name : 52536_3
# Nearest Neighbors.     : [35, 48, 43, 40, 11]
# --- 0.01 minutes passed ---------
# 36
# 24
# 26
# 29
# 19
# ---------------------------------
# Similarity index       : 36
# Master Image file name : 9905_1
# Nearest Neighbors.     : [36, 24, 26, 29, 19]
# --- 0.01 minutes passed ---------
# 37
# 44
# 24
# 30
# 31
# ---------------------------------
# Similarity index       : 37
# Master Image file name : 33220_2
# Nearest Neighbors.     : [37, 44, 24, 30, 31]
# --- 0.01 minutes passed ---------
# 38
# 45
# 42
# 34
# 37
# ---------------------------------
# Similarity index       : 38
# Master Image file name : 33220_3
# Nearest Neighbors.     : [38, 45, 42, 34, 37]
# --- 0.01 minutes passed ---------
# 39
# 28
# 13
# 10
# 6
# ---------------------------------
# Similarity index       : 39
# Master Image file name : 9905_0
# Nearest Neighbors.     : [39, 28, 13, 10, 6]
# --- 0.01 minutes passed ---------
# 40
# 48
# 46
# 35
# 37
# ---------------------------------
# Similarity index       : 40
# Master Image file name : 52536_2
# Nearest Neighbors.     : [40, 48, 46, 35, 37]
# --- 0.01 minutes passed ---------
# 41
# 11
# 29
# 19
# 43
# ---------------------------------
# Similarity index       : 41
# Master Image file name : 21857_3
# Nearest Neighbors.     : [41, 11, 29, 19, 43]
# --- 0.01 minutes passed ---------
# 42
# 34
# 38
# 45
# 49
# ---------------------------------
# Similarity index       : 42
# Master Image file name : 21857_1
# Nearest Neighbors.     : [42, 34, 38, 45, 49]
# --- 0.01 minutes passed ---------
# 43
# 35
# 37
# 48
# 49
# ---------------------------------
# Similarity index       : 43
# Master Image file name : 52536_0
# Nearest Neighbors.     : [43, 35, 37, 48, 49]
# --- 0.01 minutes passed ---------
# 44
# 37
# 30
# 31
# 32
# ---------------------------------
# Similarity index       : 44
# Master Image file name : 33220_1
# Nearest Neighbors.     : [44, 37, 30, 31, 32]
# --- 0.01 minutes passed ---------
# 45
# 38
# 44
# 37
# 42
# ---------------------------------
# Similarity index       : 45
# Master Image file name : 29000_1
# Nearest Neighbors.     : [45, 38, 44, 37, 42]
# --- 0.01 minutes passed ---------
# 46
# 40
# 15
# 24
# 25
# ---------------------------------
# Similarity index       : 46
# Master Image file name : 29000_0
# Nearest Neighbors.     : [46, 40, 15, 24, 25]
# --- 0.01 minutes passed ---------
# 47
# 12
# 48
# 40
# 37
# ---------------------------------
# Similarity index       : 47
# Master Image file name : 33220_0
# Nearest Neighbors.     : [47, 12, 48, 40, 37]
# --- 0.01 minutes passed ---------
# 48
# 40
# 35
# 37
# 47
# ---------------------------------
# Similarity index       : 48
# Master Image file name : 52536_1
# Nearest Neighbors.     : [48, 40, 35, 37, 47]
# --- 0.01 minutes passed ---------
# 49
# 1
# 43
# 24
# 17
# ---------------------------------
# Similarity index       : 49
# Master Image file name : 21857_0
# Nearest Neighbors.     : [49, 1, 43, 24, 17]
# --- 0.01 minutes passed ---------
# Step.2 - Similarity score calculation - Finished
# Step.3 - Data stored in 'nearest_neighbors.json' file
# --- Prosess completed in 0.01 minutes ---------
