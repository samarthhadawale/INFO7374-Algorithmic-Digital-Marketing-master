# %%
#################################################
# Imports and function definitions
#################################################
# For running inference on the TF-Hub module.
import tensorflow as tf
import tensorflow_hub as hub

# For saving 'feature vectors' into a txt file
import numpy as np

# Time for measuring the process time
import time

# Glob for reading file names in a folder
import glob
import os.path
#################################################

# %%
#################################################
# This function:
# Loads the JPEG image at the given path
# Decodes the JPEG image to a uint8 W X H X 3 tensor
# Resizes the image to 224 x 224 x 3 tensor
# Returns the pre processed image as 224 x 224 x 3 tensor
#################################################
def load_img(path):

  # Reads the image file and returns data type of string
  img = tf.io.read_file(path)

  # Decodes the image to W x H x 3 shape tensor with type of uint8
  img = tf.io.decode_jpeg(img, channels=3)

  # Resize the image to 224 x 244 x 3 shape tensor
  img = tf.image.resize_with_pad(img, 224, 224)

  # Converts the data type of uint8 to float32 by adding a new axis
  # This makes the img 1 x 224 x 224 x 3 tensor with the data type of float32
  # This is required for the mobilenet model we are using
  img  = tf.image.convert_image_dtype(img, tf.float32)[tf.newaxis, ...]

  return img

# %%
#################################################
# This function:
# Loads the mobilenet model in TF.HUB
# Makes an inference for all images stored in a local folder
# Saves each of the feature vectors in a file
#################################################
def get_image_feature_vectors():

  i = 0

  start_time = time.time()

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at %s" %time.ctime())
  print("---------------------------------")

  # Definition of module with using tfhub.dev handle
  module_handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_140_224/feature_vector/4" 
  
  # Load the module
  module = hub.load(module_handle)

  print("---------------------------------")
  print ("Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))

  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors -  Started at %s" %time.ctime())
 

  # Loops through all images in a local folder
  for filename in glob.glob('test/*.jpg'): #assuming gif
    i = i + 1

    print("-----------------------------------------------------------------------------------------")
    print("Image count                     :%s" %i)
    print("Image in process is             :%s" %filename)

    # Loads and pre-process the image
    img = load_img(filename)

    # Calculate the image feature vector of the img
    features = module(img)   
  
    # Remove single-dimensional entries from the 'features' array
    feature_set = np.squeeze(features)  

    # Saves the image feature vectors into a file for later use

    outfile_name = os.path.basename(filename).split('.')[0] + ".npz"
    out_path = os.path.join('test/', outfile_name)

    # Saves the 'feature_set' to a text file
    np.savetxt(out_path, feature_set, delimiter=',')

    print("Image feature vector saved to   :%s" %out_path)
  
  print("---------------------------------")
  print ("Step.2 of 2 - Generating Feature Vectors - Completed at %s" %time.ctime())
  print("--- %.2f minutes passed ---------" % ((time.time() - start_time)/60))
  print("--- %s images processed ---------" %i)
    
get_image_feature_vectors()
# Out:
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Started at Fri Jul 10 17:40:47 2020
# ---------------------------------
# ---------------------------------
# Step.1 of 2 - mobilenet_v2_140_224 - Loading Completed at Fri Jul 10 17:41:01 2020
# --- 0.24 minutes passed ---------
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors -  Started at Fri Jul 10 17:41:01 2020
# -----------------------------------------------------------------------------------------
# Image count                     :1
# Image in process is             :test/34762_2.jpg
# Image feature vector saved to   :test/34762_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :2
# Image in process is             :test/34762_0.jpg
# Image feature vector saved to   :test/34762_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :3
# Image in process is             :test/34762_1.jpg
# Image feature vector saved to   :test/34762_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :4
# Image in process is             :test/12688_0.jpg
# Image feature vector saved to   :test/12688_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :5
# Image in process is             :test/36756_3.jpg
# Image feature vector saved to   :test/36756_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :6
# Image in process is             :test/36756_2.jpg
# Image feature vector saved to   :test/36756_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :7
# Image in process is             :test/12688_1.jpg
# Image feature vector saved to   :test/12688_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :8
# Image in process is             :test/36756_0.jpg
# Image feature vector saved to   :test/36756_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :9
# Image in process is             :test/36756_1.jpg
# Image feature vector saved to   :test/36756_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :10
# Image in process is             :test/43354_2.jpg
# Image feature vector saved to   :test/43354_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :11
# Image in process is             :test/49335_0.jpg
# Image feature vector saved to   :test/49335_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :12
# Image in process is             :test/17518_3.jpg
# Image feature vector saved to   :test/17518_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :13
# Image in process is             :test/17518_2.jpg
# Image feature vector saved to   :test/17518_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :14
# Image in process is             :test/49335_1.jpg
# Image feature vector saved to   :test/49335_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :15
# Image in process is             :test/30918_2.jpg
# Image feature vector saved to   :test/30918_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :16
# Image in process is             :test/43354_1.jpg
# Image feature vector saved to   :test/43354_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :17
# Image in process is             :test/30918_0.jpg
# Image feature vector saved to   :test/30918_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :18
# Image in process is             :test/17518_0.jpg
# Image feature vector saved to   :test/17518_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :19
# Image in process is             :test/35231_0.jpg
# Image feature vector saved to   :test/35231_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :20
# Image in process is             :test/35231_1.jpg
# Image feature vector saved to   :test/35231_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :21
# Image in process is             :test/17518_1.jpg
# Image feature vector saved to   :test/17518_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :22
# Image in process is             :test/30918_1.jpg
# Image feature vector saved to   :test/30918_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :23
# Image in process is             :test/43354_0.jpg
# Image feature vector saved to   :test/43354_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :24
# Image in process is             :test/20730_1.jpg
# Image feature vector saved to   :test/20730_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :25
# Image in process is             :test/20730_0.jpg
# Image feature vector saved to   :test/20730_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :26
# Image in process is             :test/20730_2.jpg
# Image feature vector saved to   :test/20730_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :27
# Image in process is             :test/20730_3.jpg
# Image feature vector saved to   :test/20730_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :28
# Image in process is             :test/38983_0.jpg
# Image feature vector saved to   :test/38983_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :29
# Image in process is             :test/12600_0.jpg
# Image feature vector saved to   :test/12600_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :30
# Image in process is             :test/49884_0.jpg
# Image feature vector saved to   :test/49884_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :31
# Image in process is             :test/17126_3.jpg
# Image feature vector saved to   :test/17126_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :32
# Image in process is             :test/17126_2.jpg
# Image feature vector saved to   :test/17126_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :33
# Image in process is             :test/17126_0.jpg
# Image feature vector saved to   :test/17126_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :34
# Image in process is             :test/17126_1.jpg
# Image feature vector saved to   :test/17126_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :35
# Image in process is             :test/21857_2.jpg
# Image feature vector saved to   :test/21857_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :36
# Image in process is             :test/52536_3.jpg
# Image feature vector saved to   :test/52536_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :37
# Image in process is             :test/9905_1.jpg
# Image feature vector saved to   :test/9905_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :38
# Image in process is             :test/33220_2.jpg
# Image feature vector saved to   :test/33220_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :39
# Image in process is             :test/33220_3.jpg
# Image feature vector saved to   :test/33220_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :40
# Image in process is             :test/9905_0.jpg
# Image feature vector saved to   :test/9905_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :41
# Image in process is             :test/52536_2.jpg
# Image feature vector saved to   :test/52536_2.npz
# -----------------------------------------------------------------------------------------
# Image count                     :42
# Image in process is             :test/21857_3.jpg
# Image feature vector saved to   :test/21857_3.npz
# -----------------------------------------------------------------------------------------
# Image count                     :43
# Image in process is             :test/21857_1.jpg
# Image feature vector saved to   :test/21857_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :44
# Image in process is             :test/52536_0.jpg
# Image feature vector saved to   :test/52536_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :45
# Image in process is             :test/33220_1.jpg
# Image feature vector saved to   :test/33220_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :46
# Image in process is             :test/29000_1.jpg
# Image feature vector saved to   :test/29000_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :47
# Image in process is             :test/29000_0.jpg
# Image feature vector saved to   :test/29000_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :48
# Image in process is             :test/33220_0.jpg
# Image feature vector saved to   :test/33220_0.npz
# -----------------------------------------------------------------------------------------
# Image count                     :49
# Image in process is             :test/52536_1.jpg
# Image feature vector saved to   :test/52536_1.npz
# -----------------------------------------------------------------------------------------
# Image count                     :50
# Image in process is             :test/21857_0.jpg
# Image feature vector saved to   :test/21857_0.npz
# ---------------------------------
# Step.2 of 2 - Generating Feature Vectors - Completed at Fri Jul 10 17:41:03 2020
# --- 0.27 minutes passed ---------
# --- 50 images processed ---------
