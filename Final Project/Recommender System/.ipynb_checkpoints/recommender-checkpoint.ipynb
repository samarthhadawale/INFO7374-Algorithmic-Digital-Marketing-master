# %% [markdown]
# # Recommender System
# We built a recommender system based on the books we scraped.  The idea is that you give it a single book and it will return books you are likely to also enjoy based on their similarity to the book that are provided.

# %% [markdown]
# While there are many types of recommender systems, the two most common are *collaborative filters* and *content filters*.
#
#
# We are working on content based filtering and focus on the similarities between the actual content of the data, such as weighted ratings, similarity of authors, frequency of topics appearing in the description, and so on.  This method requires a direct 'similarity score' between items in order to compute how related they are.

# %%
import pandas as pd
import numpy as np

import string
from rake_nltk import Rake
from nltk.tokenize import wordpunct_tokenize
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
book_data = pd.read_csv('./scraper/output/pages-1-100.tsv', sep='\t')

# %% [markdown]
# ## Remove duplicates

# %%
book_data.drop_duplicates(subset='title', inplace=True)

# Resetting the index.
book_data = book_data.reset_index()

# %% [markdown]
# ## Weighted rating & top books
# We cannot take rating scores directly as they can be imbalanced.  One user rating a book 5/5 is not better than 50,000 people rating it on average 4.5.  We need some kind of algorithm to weight the rating values.
#
# [IMDB's FAQ](https://help.imdb.com/article/imdb/track-movies-tv/ratings-faq/G67Y87TFYYP6TWAV?ref_=helpms_helpart_inline#calculatetop) describes the algorithm that they use to weight the rank o movies and TV shows for the top rated lists.  It reads:
#
# $\text{Weighted Rating (WR)} = (\frac{v}{v+m} \cdot R) + (\frac{m}{v+m} \cdot C)$
#
# where
#
# * $R$ is the average rating for the movie (mean).
# * $v$ is the number of votes for the movie.
# * $m$ is the minimum number of votes to be listed (25,000 in their case)
# * $C$ is the mean vote across the whole report.
#
# We already have access to $R$ and $v$ in the columns directly.  $C$ is something we can compute from the data.  $m$ is something we can configure and tweak.  I'll begin with the 10th percentile, essentially chopping off the bottom part of the data.

# %%
C = book_data['avg_rating'].mean()
C
# Out:
# 4.0527289955780095

# %%
m = book_data['num_ratings'].quantile(0.1)
m
# Out:
# 2421.9000000000005

# %%
def weighted_rating(book, m, C):
    # Average rating for the book.
    R = book['avg_rating']
    # Total number of votes for the book.
    v = book['num_ratings']
    # IMDB formula.
    return (v / (v+m) * R) + (m / (m+v) * C)

# Calculate the weighted rating for books that are within our threshold.
book_data.loc[book_data.num_ratings > m, 'weighted_rating'] = book_data.loc[book_data.num_ratings > m].apply(lambda x: weighted_rating(x, m, C), axis=1)

# Fill the NaN values (i.e., books lower than our threshold) with a zero score.
book_data['weighted_rating'].fillna(0, inplace=True)

# %%
book_data.sort_values('weighted_rating', ascending=False).head(5)
# Out:
#       index                                              title  \
# 1525   1539                     The Complete Calvin and Hobbes
# 982     988                                  Words of Radiance
# 6306   6538  Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 1469   1481                        Harry Potter Series Box Set
# 5288   5455                               It's a Magical World
#
#                       original_title                  series language  \
# 1525  The Complete Calvin and Hobbes       Calvin and Hobbes  English
# 982                Words of Radiance  The Stormlight Archive  English
# 6306                             NaN                     NaN  English
# 1469                             NaN            Harry Potter  English
# 5288            It's a Magical World       Calvin and Hobbes  English
#
#                                        authors  avg_rating  num_ratings  \
# 1525                            Bill Watterson        4.82        33322
# 982                          Brandon Sanderson        4.76       172432
# 6306  J.K. Rowling,Mary GrandPré (Illustrator)        4.78        39132
# 1469                              J.K. Rowling        4.74       234260
# 5288                            Bill Watterson        4.76        25119
#
#       num_reviews                                             genres  \
# 1525          961  Sequential Art,Comics,Humor,Sequential Art,Gra...
# 982         10541  Fantasy,Fiction,Fantasy,Epic Fantasy,Fantasy,H...
# 6306          162          Fantasy,Young Adult,Fiction,Fantasy,Magic
# 1469         7065                        Fantasy,Young Adult,Fiction
# 5288          334  Sequential Art,Comics,Humor,Fiction,Sequential...
#
#                                             description  \
# 1525  [   Box Set | Book One | Book Two | Book Three...
# 982   From #1 New York Times bestselling author Bran...
# 6306  Box Set containing Harry Potter and the Sorcer...
# 1469  Over 4000 pages of Harry Potter and his world,...
# 5288  When cartoonist Bill Watterson announced that ...
#
#                                                     url  weighted_rating
# 1525  https://www.goodreads.com/book/show/24812.The_...         4.768012
# 982   https://www.goodreads.com/book/show/17332218-w...         4.750204
# 6306  https://www.goodreads.com/book/show/8.Harry_Po...         4.737612
# 1469  https://www.goodreads.com/book/show/862041.Har...         4.732967
# 5288  https://www.goodreads.com/book/show/24814.It_s...         4.697804

# %%
book_data.sort_values('weighted_rating', ascending=False).tail(5)
# Out:
#       index                                              title  \
# 6308   6540                               Awakening Inner Guru
# 6302   6534  30 Pieces of Gold: Self Growth - How to use In...
# 6291   6520                                           The Pace
# 6282   6511                                   A Midnight Clear
# 4749   4890                                  Death of the Body
#
#         original_title          series language  \
# 6308               NaN             NaN  English
# 6302               NaN             NaN  English
# 6291          The Pace        The Pace  English
# 6282  A Midnight Clear             NaN  English
# 4749               NaN  Crossing Death  English
#
#                                    authors  avg_rating  num_ratings  \
# 6308                   Banani Ray,Amit Ray        4.78          104
# 6302  Ron Millicent,Millie Parker (Editor)        4.31          128
# 6291                        Shelena Shorts        3.70         1409
# 6282                       William Wharton        4.18         1391
# 4749                     Rick Chiantaretto        3.82          217
#
#       num_reviews                                             genres  \
# 6308           24               Spirituality,Inspirational,Self Help
# 6302            1  Novels,Inspirational,Contemporary,Adult,Self H...
# 6291          258  Young Adult,Fantasy,Romance,Fantasy,Paranormal...
# 6282           66  Fiction,Historical,Historical Fiction,War,War,...
# 4749           74  Fantasy,Fantasy,Paranormal,Fantasy,Urban Fanta...
#
#                                             description  \
# 6308  Awakening Inner Guru is a clear and straightfo...
# 6302  Inspirational Quotes – Hah - Do They Really Wo...
# 6291  Weston Wilson is not immortal and he is of thi...
# 6282  Set in the Ardennes Forest on Christmas Eve 19...
# 4749  I grew up in a world of magic. By the time I w...
#
#                                                     url  weighted_rating
# 6308  https://www.goodreads.com/book/show/8596181-aw...              0.0
# 6302  https://www.goodreads.com/book/show/27467291-3...              0.0
# 6291  https://www.goodreads.com/book/show/6599113-th...              0.0
# 6282  https://www.goodreads.com/book/show/720234.A_M...              0.0
# 4749  https://www.goodreads.com/book/show/18624197-d...              0.0

# %%
del C
del m

# %% [markdown]
# ## Content-Based Recommender System
# It will be based on the content, so we will be creating an mixture of features per book that will be used to calculate the similarity score between books.
#
# Values used are title, series that it belongs to (if any), language, author(s), genres, and identify keywords from the book's description.
#
# Instead of treating each entry equally, we can add weight to them by mentioning the words multiple times in the vector that we will use to calculate similarity.

# %%
def clean_string(s):
    # Remove stopwords and punctuation.
    stop = stopwords.words('english') + list(string.punctuation)
    return [n for n in wordpunct_tokenize(s.lower()) if n not in stop]

def create_soup(x):
    title_importance = 1
    language_importance = 1
    series_importance = 1
    authors_importance = 1
    genres_importance = 1

    soup = ''
    
    # Keywords from description.
    desc = x['description']
    if desc is not np.nan:
        rake = Rake()
        rake.extract_keywords_from_text(desc)
        desc_soup = ' '.join(list(rake.get_word_degrees().keys()))
        soup = ' '.join(filter(None, [soup, desc_soup]))
    
    # Title.
    title_soup = ' '.join(clean_string(x['title']) * title_importance)
    soup = ' '.join(filter(None, [soup, title_soup]))
    
    # Language.
    language = x['language']
    if language is not np.nan:
        language_soup = ' '.join(clean_string(language) * language_importance)
        soup = ' '.join(filter(None, [soup, language_soup]))
    
    # Series.
    series = x['series']
    if series is not np.nan:
        series_soup = ' '.join(clean_string(series) * series_importance)
        soup = ' '.join(filter(None, [soup, series_soup]))

    # Authors.
    authors = x['authors']
    if authors is not np.nan:
        author_soup = ' '.join([a.lower().replace(' ', '') for a in authors.split(',')] * authors_importance)
        soup = ' '.join(filter(None, [soup, author_soup]))
    
    # Genres.
    genres = x['genres']
    if genres is not np.nan:
        genre_soup = ' '.join([g.lower().replace(' ', '') for g in genres.split(',')] * genres_importance)
        soup = ' '.join(filter(None, [soup, genre_soup]))
    
    return soup

book_data['soup'] = book_data.apply(create_soup, axis=1)

# %%
book_data.soup.head()
# Out:
# 0    remembered enormous project weaknesses crosses...
# 1    america two decades later fiction tim taking p...
# 2    philip k life stumbles upon threatens returnin...
# 3    surrealists porsche pop help eyre affair space...
# 4    tragic christmas cookies premier interpreters ...
# Name: soup, dtype: object

# %% [markdown]
# Now it's time to create the similarity matrix between all books based on our lovely steaming soup.

# %%
count_vec = CountVectorizer()
count_matrix = count_vec.fit_transform(book_data['soup'])

from sklearn.metrics.pairwise import linear_kernel
cos_sim = cosine_similarity(count_matrix, count_matrix)

# %%
# Reverse lookup of title vs. index.
title_to_index = pd.Series(book_data.index, index=book_data['title'])

def get_recommendation(title):
    idx = title_to_index[title]
    print(idx)
    print(book_data.loc[idx].soup)
    
    scores = pd.Series(cos_sim[idx]).sort_values(ascending=False)
    book_indices = list(scores.iloc[1:11].index)
    
    print(scores[1:11])
    return book_data.iloc[book_indices]

get_recommendation('Harry Potter and the Chamber of Secrets')
# Out:
# 1643
# poisonous rival finally told girls one everyone suspects could gilderoy lockhart seem minor annoyances outrageously stuck harry second year ever says strike including bags hogwarts ron weasley spirit named moaning myrtle stone horrors arise draco malfoy mean school warning potter wanted dursleys fresh torments wizardry whose mysterious past witchcraft -- jacket description hagrid receives disaster possibly real trouble begins summer get back ginny strange unwanted attentions haunts something starts turning students hideous impish creature dobby returns new professor packing younger sister someone bathroom harry potter chamber secrets english harry potter j.k.rowling marygrandpré(illustrator) fantasy youngadult fiction
# 3308    0.410863
# 6306    0.408938
# 2762    0.380682
# 1675    0.369751
# 4940    0.361968
# 1469    0.325887
# 1739    0.320964
# 233     0.297491
# 1698    0.293085
# 1672    0.280109
# dtype: float64
#       index                                              title  \
# 3308   3382  Harry Potter and the Order of the Phoenix (Har...
# 6306   6538  Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 2762   2810                            Harry Potter Collection
# 1675   1691                Harry Potter and the Goblet of Fire
# 4940   5088                           The Harry Potter trilogy
# 1469   1481                        Harry Potter Series Box Set
# 1739   1760              Harry Potter and the Sorcerer's Stone
# 233     233                    The Harry Potter Collection 1-4
# 1698   1718               Harry Potter and the Deathly Hallows
# 1672   1688             Harry Potter and the Half-Blood Prince
#
#                                          original_title        series  \
# 3308                                                NaN           NaN
# 6306                                                NaN           NaN
# 2762       Harry Potter Collection (Harry Potter, #1-6)  Harry Potter
# 1675                Harry Potter and the Goblet of Fire  Harry Potter
# 4940  The Harry Potter trilogy: The Philosopher's St...  Harry Potter
# 1469                                                NaN  Harry Potter
# 1739           Harry Potter and the Philosopher's Stone  Harry Potter
# 233                    Harry Potter Boxed Set Books 1-4  Harry Potter
# 1698               Harry Potter and the Deathly Hallows  Harry Potter
# 1672             Harry Potter and the Half-Blood Prince  Harry Potter
#
#      language                                   authors  avg_rating  \
# 3308  English                              J.K. Rowling        4.59
# 6306  English  J.K. Rowling,Mary GrandPré (Illustrator)        4.78
# 2762  English                              J.K. Rowling        4.73
# 1675  English  J.K. Rowling,Mary GrandPré (Illustrator)        4.55
# 4940  English                              J.K. Rowling        4.66
# 1469  English                              J.K. Rowling        4.74
# 1739  English  J.K. Rowling,Mary GrandPré (Illustrator)        4.47
# 233   English  J.K. Rowling,Mary GrandPré (Illustrator)        4.67
# 1698  English                              J.K. Rowling        4.61
# 1672  English  J.K. Rowling,Mary GrandPré (Illustrator)        4.56
#
#       num_ratings  num_reviews  \
# 3308        22648          418
# 6306        39132          162
# 2762        29618          923
# 1675      2286525        40512
# 4940         6373          167
# 1469       234260         7065
# 1739      6215158        98678
# 233         48175          298
# 1698      2539759        60223
# 1672      2176421        34865
#
#                                                  genres  \
# 3308                        Fantasy,Fiction,Young Adult
# 6306          Fantasy,Young Adult,Fiction,Fantasy,Magic
# 2762          Fantasy,Fiction,Young Adult,Fantasy,Magic
# 1675                        Fantasy,Young Adult,Fiction
# 4940  Fantasy,Fiction,Young Adult,Childrens,Adventur...
# 1469                        Fantasy,Young Adult,Fiction
# 1739                        Fantasy,Young Adult,Fiction
# 233                         Fantasy,Young Adult,Fiction
# 1698                        Fantasy,Young Adult,Fiction
# 1672                        Fantasy,Young Adult,Fiction
#
#                                             description  \
# 3308                                                NaN
# 6306  Box Set containing Harry Potter and the Sorcer...
# 2762  Six years of magic, adventure, and mystery mak...
# 1675  Harry Potter is midway through his training as...
# 4940  This box set collects hard cover editions Harr...
# 1469  Over 4000 pages of Harry Potter and his world,...
# 1739  Harry Potter's life is miserable. His parents ...
# 233   The exciting tales of Harry Potter, the young ...
# 1698  Harry Potter is leaving Privet Drive for the l...
# 1672  When Harry Potter and the Half-Blood Prince op...
#
#                                                     url  weighted_rating  \
# 3308  https://www.goodreads.com/book/show/1317181.Ha...         4.538096
# 6306  https://www.goodreads.com/book/show/8.Harry_Po...         4.737612
# 2762  https://www.goodreads.com/book/show/10.Harry_P...         4.678805
# 1675  https://www.goodreads.com/book/show/6.Harry_Po...         4.549474
# 4940  https://www.goodreads.com/book/show/2337379.Th...         4.492772
# 1469  https://www.goodreads.com/book/show/862041.Har...         4.732967
# 1739  https://www.goodreads.com/book/show/3.Harry_Po...         4.469837
# 233   https://www.goodreads.com/book/show/99298.The_...         4.640453
# 1698  https://www.goodreads.com/book/show/136251.Har...         4.609469
# 1672  https://www.goodreads.com/book/show/1.Harry_Po...         4.559436
#
#                                                    soup
# 3308  harry potter order phoenix harry potter 5 part...
# 6306  secrets goblet harry potter prisoner stone box...
# 2762  elegant hardcover boxed set ages thrilling sea...
# 1675  normal take place hundred years find age -- ba...
# 4940  secrets harry potter prisoner stone slip case ...
# 1469  internationally bestselling harry potter serie...
# 1739  perfect relatives killing curse inflicted kill...
# 233   seem books storm easy buy one sorry -- next ch...
# 1698  one final battle destroy enemy leaving privet ...
# 1672  apparate objects fascinating fall disposal dum...

# %% [markdown]
# pickle files for loading elsewhere

# %%
import pickle

should_export = False

if should_export:
    # Book data.
    print('Exporting book data...', end='')
    pickle.dump(book_data, open('book_data.pickle', 'wb'))
    print('done!')
    
    # Cosine similarity (warning: this will be huge).
    print('Exporting similarity matrix...', end='')
    pickle.dump(cos_sim, open('cossim.pickle', 'wb'))
    print('done!')

# %%
book_data.loc[book_data.title.str.contains('Harry')]
# Out:
#       index                                              title  \
# 233     233                    The Harry Potter Collection 1-4
# 402     404  Harry Potter and the Cursed Child: Parts One a...
# 1469   1481                        Harry Potter Series Box Set
# 1643   1659            Harry Potter and the Chamber of Secrets
# 1672   1688             Harry Potter and the Half-Blood Prince
# 1675   1691                Harry Potter and the Goblet of Fire
# 1679   1695           Harry Potter and the Prisoner of Azkaban
# 1698   1718               Harry Potter and the Deathly Hallows
# 1739   1760              Harry Potter and the Sorcerer's Stone
# 1773   1797          Harry Potter and the Order of the Phoenix
# 2564   2608        Harry Potter and the Methods of Rationality
# 2762   2810                            Harry Potter Collection
# 3308   3382  Harry Potter and the Order of the Phoenix (Har...
# 3329   3407     Harry Potter and the Cursed Child, Parts 1 & 2
# 4657   4790              La Vérité sur l'affaire Harry Quebert
# 4793   4936            The First Fifteen Lives of Harry August
# 4940   5088                           The Harry Potter trilogy
# 6306   6538  Harry Potter Boxed Set, Books 1-5 (Harry Potte...
# 7378   7708                        Harry Potter: Film Wizardry
# 7396   7727                   La verità sul caso Harry Quebert
#
#                                          original_title          series  \
# 233                    Harry Potter Boxed Set Books 1-4    Harry Potter
# 402   Harry Potter and the Cursed Child: Parts One a...    Harry Potter
# 1469                                                NaN    Harry Potter
# 1643            Harry Potter and the Chamber of Secrets    Harry Potter
# 1672             Harry Potter and the Half-Blood Prince    Harry Potter
# 1675                Harry Potter and the Goblet of Fire    Harry Potter
# 1679           Harry Potter and the Prisoner of Azkaban    Harry Potter
# 1698               Harry Potter and the Deathly Hallows    Harry Potter
# 1739           Harry Potter and the Philosopher's Stone    Harry Potter
# 1773          Harry Potter and the Order of the Phoenix    Harry Potter
# 2564        Harry Potter and the Methods of Rationality             NaN
# 2762       Harry Potter Collection (Harry Potter, #1-6)    Harry Potter
# 3308                                                NaN             NaN
# 3329  Harry Potter and the Cursed Child: Parts One a...    Harry Potter
# 4657              La Vérité sur l'affaire Harry Quebert  Marcus Goldman
# 4793            The First Fifteen Lives of Harry August             NaN
# 4940  The Harry Potter trilogy: The Philosopher's St...    Harry Potter
# 6306                                                NaN             NaN
# 7378                        Harry Potter: Film Wizardry             NaN
# 7396              La Vérité sur l'affaire Harry Quebert  Marcus Goldman
#
#      language                                            authors  avg_rating  \
# 233   English           J.K. Rowling,Mary GrandPré (Illustrator)        4.67
# 402   English  John Tiffany (Adaptation),Jack Thorne,J.K. Row...        3.66
# 1469  English                                       J.K. Rowling        4.74
# 1643  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.41
# 1672  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.56
# 1675  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.55
# 1679  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.56
# 1698  English                                       J.K. Rowling        4.61
# 1739  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.47
# 1773  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.49
# 2564  English                                  Eliezer Yudkowsky        4.39
# 2762  English                                       J.K. Rowling        4.73
# 3308  English                                       J.K. Rowling        4.59
# 3329  English  John Tiffany (Adaptation),Jack Thorne (Adaptat...        3.66
# 4657   French                                        Joël Dicker        4.03
# 4793  English                                       Claire North        4.04
# 4940  English                                       J.K. Rowling        4.66
# 6306  English           J.K. Rowling,Mary GrandPré (Illustrator)        4.78
# 7378  English                                       Brian Sibley        4.49
# 7396  Italian             Joël Dicker,Vincenzo Vega (Translator)        4.03
#
#       num_ratings  num_reviews  \
# 233         48175          298
# 402        592249        62023
# 1469       234260         7065
# 1643      2401147        45913
# 1672      2176421        34865
# 1675      2286525        40512
# 1679      2443994        48308
# 1698      2539759        60223
# 1739      6215158        98678
# 1773      2231129        37092
# 2564        12187         1224
# 2762        29618          923
# 3308        22648          418
# 3329       592278        62024
# 4657        71420         8260
# 4793        56816         7490
# 4940         6373          167
# 6306        39132          162
# 7378        54542          551
# 7396        71408         8258
#
#                                                  genres  \
# 233                         Fantasy,Young Adult,Fiction
# 402                   Fantasy,Fiction,Young Adult,Plays
# 1469                        Fantasy,Young Adult,Fiction
# 1643                        Fantasy,Young Adult,Fiction
# 1672                        Fantasy,Young Adult,Fiction
# 1675                        Fantasy,Young Adult,Fiction
# 1679                        Fantasy,Young Adult,Fiction
# 1698                        Fantasy,Young Adult,Fiction
# 1739                        Fantasy,Young Adult,Fiction
# 1773                        Fantasy,Young Adult,Fiction
# 2564             Fantasy,Fiction,Fan Fiction,Philosophy
# 2762          Fantasy,Fiction,Young Adult,Fantasy,Magic
# 3308                        Fantasy,Fiction,Young Adult
# 3329                  Fantasy,Fiction,Young Adult,Plays
# 4657  Fiction,Mystery,Thriller,Mystery,Crime,Cultura...
# 4793  Science Fiction,Fiction,Fantasy,Science Fictio...
# 4940  Fantasy,Fiction,Young Adult,Childrens,Adventur...
# 6306          Fantasy,Young Adult,Fiction,Fantasy,Magic
# 7378                                         Nonfiction
# 7396  Fiction,Mystery,Thriller,Mystery,Crime,Cultura...
#
#                                             description  \
# 233   The exciting tales of Harry Potter, the young ...
# 402   Based on an original new story by J.K. Rowling...
# 1469  Over 4000 pages of Harry Potter and his world,...
# 1643  The Dursleys were so mean and hideous that sum...
# 1672  When Harry Potter and the Half-Blood Prince op...
# 1675  Harry Potter is midway through his training as...
# 1679  Harry Potter's third year at Hogwarts is full ...
# 1698  Harry Potter is leaving Privet Drive for the l...
# 1739  Harry Potter's life is miserable. His parents ...
# 1773  There is a door at the end of a silent corrido...
# 2564  Harry Potter and the Methods of Rationality is...
# 2762  Six years of magic, adventure, and mystery mak...
# 3308                                                NaN
# 3329  The eight story, nineteen years later … Based ...
# 4657  À New York, au printemps 2008, alors que l’Amé...
# 4793  Some stories cannot be told in just one lifeti...
# 4940  This box set collects hard cover editions Harr...
# 6306  Box Set containing Harry Potter and the Sorcer...
# 7378  Harry Potter: Film Wizardry gives readers a fr...
# 7396  Estate 1975. Nola Kellergan, una ragazzina di ...
#
#                                                     url  weighted_rating  \
# 233   https://www.goodreads.com/book/show/99298.The_...         4.640453
# 402   https://www.goodreads.com/book/show/29056083-h...         3.661599
# 1469  https://www.goodreads.com/book/show/862041.Har...         4.732967
# 1643  https://www.goodreads.com/book/show/15881.Harr...         4.409640
# 1672  https://www.goodreads.com/book/show/1.Harry_Po...         4.559436
# 1675  https://www.goodreads.com/book/show/6.Harry_Po...         4.549474
# 1679  https://www.goodreads.com/book/show/5.Harry_Po...         4.559498
# 1698  https://www.goodreads.com/book/show/136251.Har...         4.609469
# 1739  https://www.goodreads.com/book/show/3.Harry_Po...         4.469837
# 1773  https://www.goodreads.com/book/show/2.Harry_Po...         4.489526
# 2564  https://www.goodreads.com/book/show/10016013-h...         4.334086
# 2762  https://www.goodreads.com/book/show/10.Harry_P...         4.678805
# 3308  https://www.goodreads.com/book/show/1317181.Ha...         4.538096
# 3329  https://www.goodreads.com/book/show/29069989-h...         3.661599
# 4657  https://www.goodreads.com/book/show/16033842-l...         4.030745
# 4793  https://www.goodreads.com/book/show/20706317-t...         4.040520
# 4940  https://www.goodreads.com/book/show/2337379.Th...         4.492772
# 6306  https://www.goodreads.com/book/show/8.Harry_Po...         4.737612
# 7378  https://www.goodreads.com/book/show/7952502-ha...         4.471409
# 7396  https://www.goodreads.com/book/show/17981035-l...         4.030746
#
#                                                    soup
# 233   seem books storm easy buy one sorry -- next ch...
# 402   receive stage darkness comes john tiffany new ...
# 1469  internationally bestselling harry potter serie...
# 1643  poisonous rival finally told girls one everyon...
# 1672  apparate objects fascinating fall disposal dum...
# 1675  normal take place hundred years find age -- ba...
# 1679  seem azkaban guards terrible power becomes clo...
# 1698  one final battle destroy enemy leaving privet ...
# 1739  perfect relatives killing curse inflicted kill...
# 1773  things pale next night boundless loyalty middl...
# 2564  science oxford biochemistry professor work alt...
# 2762  elegant hardcover boxed set ages thrilling sea...
# 3308  harry potter order phoenix harry potter 5 part...
# 3329  receive stage darkness comes john tiffany new ...
# 4657  au printemps 2008 ’ est que écrivain il passé ...
# 4793  save nearly missed cannot change send life sto...
# 4940  secrets harry potter prisoner stone slip case ...
# 6306  secrets goblet harry potter prisoner stone box...
# 7378  brian sibley front row seat like rings step ro...
# 7396  poco dovrebbe consegnare al suo editore il ami...
